# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pprint

# %%
CSV_PATH = '/mnt/c/Users/User/Documents/GitHub/Last-Mile-206/datasets/final.csv'

# %%
# Loading the dataset
df = pd.read_csv(CSV_PATH)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x              Country Country Code  \
# 0           0           1.0          Afghanistan          AFG
# 1           1           3.0              Albania          ALB
# 2           2          58.0              Algeria          DZA
# 3           3           2.0               Angola          AGO
# 4           4          10.0  Antigua and Barbuda          ATG
#
#                            Indicator Name  Indicator Code      1980      1981  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.131783  0.150615
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.935058  2.693024
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  3.460646  2.342523
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.640966  0.611135
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2.311695  1.720761
#
#        1982      1983  ...  acc_bal_2013  acc_bal_2014  acc_bal_2015  \
# ...

# %%
TEST_CSV = "/mnt/c/Users/User/Documents/GitHub/Last-Mile-206/src/california_housing_train.csv"

# %%
df = pd.read_csv(TEST_CSV)

# %%
x_train = df.iloc[0:1000, 0:8].copy()
print(x_train)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -114.31     34.19                15.0       5612.0          1283.0
# 1      -114.47     34.40                19.0       7650.0          1901.0
# 2      -114.56     33.69                17.0        720.0           174.0
# 3      -114.57     33.64                14.0       1501.0           337.0
# 4      -114.57     33.57                20.0       1454.0           326.0
# ..         ...       ...                 ...          ...             ...
# 995    -117.09     32.55                 8.0       6533.0          1217.0
# 996    -117.10     34.57                 6.0       5110.0          1044.0
# 997    -117.10     34.21                22.0       4397.0           931.0
# 998    -117.10     34.03                24.0       4144.0           826.0
# 999    -117.10     33.56                 6.0       1868.0           289.0
#
#      population  households  median_income
# ...

# %%
y_train = df.iloc[:1000, 8].copy()
print(y_train)
# Out:
# 0       66900.0
# 1       80100.0
# 2       85700.0
# 3       73400.0
# 4       65500.0
#          ...
# 995    144400.0
# 996    112800.0
# 997    108400.0
# 998     96000.0
# 999    307600.0
# Name: median_house_value, Length: 1000, dtype: float64

# %%
plt.scatter(x_train['median_income'], y_train, c=['lightblue'])
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
